# %% [markdown]
# # Skills with Claude API

# %%
from dotenv import load_dotenv
import anthropic
from anthropic.lib import files_from_dir

_ = load_dotenv()

# %%
client = anthropic.Anthropic()

# %% [markdown]
# ## Part 1 : Content Creation

# %% [markdown]
# ### Upload the Custom Skill: Practice Question Generator

# %%
# Upload your skill directory
skill = client.beta.skills.create(
    display_title="Practice Question Generator",
    files=files_from_dir("./custom_skills/generating-practice-questions"),
    betas=["skills-2025-10-02"]
)

print(f"Skill ID: {skill.id}")
# Out:
# Skill ID: skill_01Ex1s2aAvVXjHdhYihr5mVV

# %%
skills = client.beta.skills.list(source="custom")

# %%
for custom_skill in skills:
    print(f"ID: {skill.id}. Display Title: {skill.display_title}")
# Out:
# ID: skill_01Ex1s2aAvVXjHdhYihr5mVV. Display Title: Practice Question Generator

# %% [markdown]
# ### Upload the Input File

# %%
file_object = client.beta.files.upload(
    file=open("./lecture_notes/notes04.tex", "rb"),
)

# %% [markdown]
# ### Send the Request

# %%
response = client.beta.messages.create(
    model="claude-sonnet-4-5-20250929",
    max_tokens=4096,
    betas=["code-execution-2025-08-25","skills-2025-10-02", "files-api-2025-04-14"],  
    container={
        "skills": [{
            "type": "custom", 
            "skill_id": skill.id, 
            "version": "latest"}]
    },
    messages=[{
        "role": "user",
        "content": [
            {"type": "text", "text": "Generate practice questions in Markdown format from these lecture notes"},
            {"type": "container_upload", "file_id": file_object.id}
        ]
    }],
    tools=[{
        "type": "code_execution_20250825",
        "name": "code_execution"
    }]
)

# %%
for block in response.content:
    print(block.type)
# Out:
# text
# server_tool_use
# server_tool_use
# text_editor_code_execution_tool_result
# text_editor_code_execution_tool_result
# text
# server_tool_use
# text_editor_code_execution_tool_result
# text
# server_tool_use
# text_editor_code_execution_tool_result
# text
# server_tool_use
# bash_code_execution_tool_result
# text

# %%
# Color codes
BOLD = "\033[1m"
RESET = "\033[0m"
BLUE = "\033[94m"
GREEN = "\033[92m"
YELLOW = "\033[93m"
CYAN = "\033[96m"

# %%
for block in response.content:
    if block.type == "text":
        print(f"{BOLD}{BLUE}[TEXT]{RESET}")
        print(block.text, "\n")
    
    if block.type == "server_tool_use":
        print(f"{BOLD}{GREEN}[SERVER_TOOL_USE]{RESET}")
        input_preview = block.input.copy()  
        if "file_text" in input_preview:
            text = input_preview["file_text"]
            if len(text) > 100:
                input_preview["file_text"] = text[:100] + " ..."
        print(input_preview, "\n")
    
    if block.type == "text_editor_code_execution_tool_result":
        print(f"{BOLD}{YELLOW}[TOOL_RESULT]{RESET}")
        content_str = str(block.content)
        preview = content_str[:100]
        if len(content_str) > 100:
            preview += " ..."
        print(preview, "\n")
    
    if block.type == "bash_code_execution_tool_result":
        print(f"{BOLD}{CYAN}[BASH_RESULT]{RESET}")
        print(block.content, "\n")
# Out:
# [TEXT]
# I'll help you generate practice questions from the lecture notes. Let me start by reading the skill file and then examining your lecture notes.
#
# [SERVER_TOOL_USE]
# {'command': 'view', 'path': '/skills/generating-practice-questions/SKILL.md'}
#
# [SERVER_TOOL_USE]
# {'command': 'view', 'path': '$INPUT_DIR/notes04.tex'}
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionViewResultBlock(content='---\nname: generating-practice-questions\ndescri ...
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionViewResultBlock(content="\\documentclass[11pt,letterpaper]{article}\n\\us ...
#
# [TEXT]
# Now let me check the Markdown template to use the proper structure:
#
# [SERVER_TOOL_USE]
# {'command': 'view', 'path': '/skills/generating-practice-questions/assets/markdown_template.md'}
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionViewResultBlock(content='# Markdown Template for Practice Questions\n\nUs ...
#
# [TEXT]
# Perfect! Now I'll generate comprehensive practice questions based on the lecture notes about Machine Learning Models. Let me create the practice questions document:
#
# [SERVER_TOOL_USE]
# {'command': 'create', 'path': '/tmp/practice_questions_notes04.md', 'file_text': '# Practice Questions for Machine Learning Models\n\n## Instructions\n\nThese practice questions are desi ...'}
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionCreateResultBlock(is_file_update=False, type='text_editor_code_execution_ ...
#
# [TEXT]
# Now let me copy the file to the output directory:
#
# [SERVER_TOOL_USE]
# {'command': 'cp /tmp/practice_questions_notes04.md $OUTPUT_DIR/practice_questions_notes04.md'}
#
# [BASH_RESULT]
# BetaBashCodeExecutionResultBlock(content=[BetaBashCodeExecutionOutputBlock(file_id='file_011CX4CmpLTLPgYBa3ZHLebS', type='bash_code_execution_output')], return_code=0, stderr='', stdout='', type='bash_code_execution_result')
#
# [TEXT]
# Perfect! I've successfully generated comprehensive practice questions in Markdown format from your lecture notes on Machine Learning Models. Here's what I created:
#
# ## Summary of Practice Questions
#
# The document includes **12 questions** organized into 4 parts:
#
# ### Part 1: True/False Questions (5 questions)
# - Tests fundamental concepts about models, parametric vs non-parametric models, and linear models
# - Progresses from simple definitional questions to reasoning-based questions that test deeper understanding
#
# ### Part 2: Explanatory Questions (5 questions)
# - Covers key topics including:
#   - Model parameters vs inputs
#   - Parametric vs non-parametric models comparison
#   - Geometric interpretation of linear classification
#   - Model limitations and George Box's famous quote
#   - Training objectives for linear regression
#
# ### Part 3: Coding Question (1 question)
# - **Implement Simple Linear Regression from Scratch**
# - Requires students to implement the closed-form solution for finding optimal weights
# - Includes step-by-step instructions, function signatures, examples, and helpful hints
# - Takes about 20-30 minutes for a prepared student
#
# ### Part 4: Use Case Application (1 question)
# - **Predicting Student Admission with Linear Classification**
# - Realistic scenario using GRE scores and CGPA to predict university admission
# - Includes complete data generation code
# - Requires training a logistic regression model, evaluating it, and visualizing the decision boundary
# - Tests ability to apply lecture concepts to a practical problem
#
# The questions align with the four learning objectives stated in your lecture notes and cover all major topics including models, linear models, geometric interpretation, parametric/non-parametric distinctions, and training procedures.
#
# The file has been saved as **practice_questions_notes04.md** and is ready for use!

# %% [markdown]
# ### Download the File

# %%
# Extract file ID from response
file_id = None
for block in response.content:
    if block.type == 'bash_code_execution_tool_result':
        # File ID is in the tool result
        if hasattr(block, 'content') and hasattr(block.content, 'content'):
            for result_block in block.content.content:
                if hasattr(result_block, 'file_id'):
                    file_id = result_block.file_id
                    break

# %%
if file_id:
    # Download the file
    file_content = client.beta.files.download(
        file_id=file_id,
        betas=["files-api-2025-04-14"]
    )

    # Save to disk
    with open("notes04.md", "wb") as f:
        file_content.write_to_file(f.name)

# %% [markdown]
# ### Delete the Skill - Optional

# %%
# Step 1: Delete all versions
versions = client.beta.skills.versions.list(
    skill_id=skill.id,
    betas=["skills-2025-10-02"]
)

for version in versions.data:
    client.beta.skills.versions.delete(
        skill_id=skill.id,
        version=version.version,
        betas=["skills-2025-10-02"]
    )

# %%
# Step 2: Delete the Skill
client.beta.skills.delete(
    skill_id=skill.id,
    betas=["skills-2025-10-02"]
)
# Out:
# SkillDeleteResponse(id='skill_01Ex1s2aAvVXjHdhYihr5mVV', type='skill_deleted')

# %% [markdown]
# ## Part 2 : Data Analysis

# %% [markdown]
# ### Upload the Custom Skill: Time Series Analysis

# %%
# Upload your skill directory
skill = client.beta.skills.create(
    display_title="Time Series Analysis",
    files=files_from_dir("./custom_skills/analyzing-time-series/"),
    betas=["skills-2025-10-02"]
)

print(f"Skill ID: {skill.id}")
# Out:
# Skill ID: skill_01WmT3LwX2Vpc2CYZpahhkoL

# %%
skills = client.beta.skills.list()
for sk in skills:
    print(f"ID: {sk.id}. Display Title: {sk.display_title}. Version: {sk.latest_version}")
# Out:
# ID: skill_01WmT3LwX2Vpc2CYZpahhkoL. Display Title: Time Series Analysis. Version: 1768254310772750
# ID: xlsx. Display Title: xlsx. Version: 20251013
# ID: pptx. Display Title: pptx. Version: 20251013
# ID: pdf. Display Title: pdf. Version: 20251013
# ID: docx. Display Title: docx. Version: 20251013

# %% [markdown]
# ### Upload the Input File

# %%
file_object = client.beta.files.upload(
    file=open("./data/retail_sales.csv", "rb"),
)

# %% [markdown]
# ### Send the Request

# %%
query= """
Analyze and visualize this time series data. 
Create a word doc report summarizing the diagnostic results and plots.
"""

# %%
response = client.beta.messages.create(
    model="claude-sonnet-4-5-20250929",
    max_tokens=16384,
    betas=["code-execution-2025-08-25","skills-2025-10-02", "files-api-2025-04-14"],  
    container={
        "skills": [
            {"type": "custom", "skill_id": skill.id, "version": "latest"},
            {"type": "anthropic", "skill_id":"docx", "version": "20251013"}
        ]
    },
    messages=[{
        "role": "user",
        "content": [
            {"type": "text", "text": query},
            {"type": "container_upload", "file_id": file_object.id}
        ]
    }],
    tools=[{
        "type": "code_execution_20250825",
        "name": "code_execution"
    }]
)

# %%
for block in response.content:
    print(block.type)
# Out:
# text
# server_tool_use
# server_tool_use
# text_editor_code_execution_tool_result
# text_editor_code_execution_tool_result
# text
# server_tool_use
# bash_code_execution_tool_result
# text
# server_tool_use
# bash_code_execution_tool_result
# server_tool_use
# bash_code_execution_tool_result
# text
# server_tool_use
# text_editor_code_execution_tool_result
# text
# server_tool_use
# text_editor_code_execution_tool_result
# text
# server_tool_use
# text_editor_code_execution_tool_result
# text
# server_tool_use
# bash_code_execution_tool_result
# text
# server_tool_use
# bash_code_execution_tool_result
# text

# %%
for block in response.content:
    if block.type == "text":
        print(f"{BOLD}{BLUE}[TEXT]{RESET}")
        print(block.text, "\n")
    
    if block.type == "server_tool_use":
        print(f"{BOLD}{GREEN}[SERVER_TOOL_USE]{RESET}")
        input_preview = block.input.copy()  
        if "file_text" in input_preview:
            text = input_preview["file_text"]
            if len(text) > 100:
                input_preview["file_text"] = text[:100] + " ..."
        print(input_preview, "\n")
    
    if block.type == "text_editor_code_execution_tool_result":
        print(f"{BOLD}{YELLOW}[TOOL_RESULT]{RESET}")
        content_str = str(block.content)
        preview = content_str[:100]
        if len(content_str) > 100:
            preview += " ..."
        print(preview, "\n")
    
    if block.type == "bash_code_execution_tool_result":
        print(f"{BOLD}{CYAN}[BASH_RESULT]{RESET}")
        print(block.content, "\n")
# Out:
# [TEXT]
# I'll help you analyze the time series data and create a comprehensive Word document report. Let me start by reading the relevant skill files and then proceeding with the analysis.
#
# [SERVER_TOOL_USE]
# {'command': 'view', 'path': '/skills/analyzing-time-series/SKILL.md'}
#
# [SERVER_TOOL_USE]
# {'command': 'view', 'path': '/skills/docx/SKILL.md'}
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionViewResultBlock(content='---\nname: analyzing-time-series\ndescription: C ...
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionViewResultBlock(content='---\nname: docx\ndescription: "Comprehensive doc ...
#
# [TEXT]
# Now let me examine the data and run the time series analysis:
#
# [SERVER_TOOL_USE]
# {'command': 'head -20 "$INPUT_DIR/retail_sales.csv"'}
#
# [BASH_RESULT]
# BetaBashCodeExecutionResultBlock(content=[], return_code=0, stderr='', stdout='date,sales\n2015-01-01,46743\n2015-02-01,68008\n2015-03-01,71943\n2015-04-01,62245\n2015-05-01,56679\n2015-06-01,58467\n2015-07-01,46249\n2015-08-01,52259\n2015-09-01,52441\n2015-10-01,37693\n2015-11-01,33927\n2015-12-01,66758\n2016-01-01,61532\n2016-02-01,70158\n2016-03-01,76821\n2016-04-01,72520\n2016-05-01,72091\n2016-06-01,67132\n2016-07-01,63600\n', type='bash_code_execution_result')
#
# [TEXT]
# Perfect! Now let me run the time series diagnostics and create visualizations:
#
# [SERVER_TOOL_USE]
# {'command': 'cd /skills/analyzing-time-series && python scripts/diagnose.py "$INPUT_DIR/retail_sales.csv" --output-dir /tmp/results/'}
#
# [BASH_RESULT]
# BetaBashCodeExecutionResultBlock(content=[], return_code=0, stderr="/skills/analyzing-time-series/scripts/ts_utils.py:131: InterpolationWarning: The test statistic is outside of the range of p-values available in the\nlook-up table. The actual p-value is smaller than the p-value returned.\n\n  kpss_result = kpss(clean_series, regression='c', nlags='auto')\n", stdout='\n============================================================\nTIME SERIES DIAGNOSTICS\n============================================================\n\nLoaded 120 observations (2015-01-01 to 2024-12-01)\n\nRunning analyses...\n  [1/8] Data quality\n  [2/8] Distribution\n  [3/8] Stationarity tests (ADF, KPSS)\n  [4/8] Seasonality (STL decomposition)\n  [5/8] Trend analysis\n  [6/8] Autocorrelation (ACF, PACF)\n  [7/8] Forecastability (Ljung-Box)\n  [8/8] Transform recommendation (Box-Cox)\n\nOutput saved to /tmp/results/\n  - diagnostics.json\n  - summary.txt\n  - diagnostics_state.json\n\n============================================================\nQUICK SUMMARY\n============================================================\nForecastable: Yes\nStationary: No (d=1)\nSeasonal: Yes (period=12)\nTrend: increasing\n', type='bash_code_execution_result')
#
# [SERVER_TOOL_USE]
# {'command': 'cd /skills/analyzing-time-series && python scripts/visualize.py "$INPUT_DIR/retail_sales.csv" --output-dir /tmp/results/'}
#
# [BASH_RESULT]
# BetaBashCodeExecutionResultBlock(content=[], return_code=0, stderr='', stdout='Found diagnostics_state.json - synchronizing with diagnose.py results\n\nGenerating plots for 120 observations...\n\nPlots:\n  Created: timeseries.png\n  Created: histogram.png\n  Created: rolling_stats.png\n  Created: box_by_month.png\n  Created: box_by_quarter.png\n  Created: acf_pacf.png (first difference (d=1))\n  Created: decomposition.png (period=12)\n  Created: lag_scatter.png\n\nAll plots saved to: /tmp/results/plots/\n[OK] Plots synchronized with diagnose.py results\n', type='bash_code_execution_result')
#
# [TEXT]
# Now let me read the summary and diagnostics:
#
# [SERVER_TOOL_USE]
# {'command': 'view', 'path': '/tmp/results/summary.txt'}
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionViewResultBlock(content='TIME SERIES DIAGNOSTICS SUMMARY\n=============== ...
#
# [TEXT]
# Now let me read the docx-js.md file to create the Word document report:
#
# [SERVER_TOOL_USE]
# {'command': 'view', 'path': '/skills/docx/docx-js.md'}
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionViewResultBlock(content='# DOCX Library Tutorial\n\nGenerate .docx files  ...
#
# [TEXT]
# Now let me create a comprehensive Word document report with the time series analysis results and embedded plots:
#
# [SERVER_TOOL_USE]
# {'command': 'create', 'path': '/tmp/create_report.js', 'file_text': 'const { Document, Packer, Paragraph, TextRun, Table, TableRow, TableCell, ImageRun, \n        Alignme ...'}
#
# [TOOL_RESULT]
# BetaTextEditorCodeExecutionCreateResultBlock(is_file_update=False, type='text_editor_code_execution_ ...
#
# [TEXT]
# Now let me run the script to generate the Word document:
#
# [SERVER_TOOL_USE]
# {'command': 'cd /tmp && node create_report.js'}
#
# [BASH_RESULT]
# BetaBashCodeExecutionResultBlock(content=[], return_code=0, stderr='', stdout='Report created successfully!\n', type='bash_code_execution_result')
#
# [TEXT]
# Perfect! Now let me copy the report to the output directory:
#
# [SERVER_TOOL_USE]
# {'command': 'cp /tmp/retail_sales_analysis_report.docx "$OUTPUT_DIR/" && ls -lh "$OUTPUT_DIR/"'}
#
# [BASH_RESULT]
# BetaBashCodeExecutionResultBlock(content=[BetaBashCodeExecutionOutputBlock(file_id='file_011CX4DoGAcf5QcuDz6fsEfq', type='bash_code_execution_output')], return_code=0, stderr='', stdout='total 680K\n-rw-r--r-- 1 root root 680K Jan 12 21:49 retail_sales_analysis_report.docx\n', type='bash_code_execution_result')
#
# [TEXT]
# Excellent! I've successfully completed the time series analysis and created a comprehensive Word document report. Here's what was accomplished:
#
# ## Summary
#
# ### Time Series Analysis Completed:
# 1. **Diagnostic Tests Run:**
#    - Data quality assessment (120 monthly observations, no missing values)
#    - Distribution analysis (skewness, kurtosis)
#    - Stationarity tests (ADF, KPSS)
#    - Seasonality detection (STL decomposition)
#    - Trend analysis
#    - Autocorrelation analysis (ACF, PACF)
#    - Forecastability assessment (Ljung-Box tests)
#    - Transformation recommendations (Box-Cox)
#
# 2. **Visualizations Created:**
#    - Time series plot
#    - Distribution histogram
#    - Rolling statistics
#    - Monthly and quarterly box plots
#    - ACF/PACF plots
#    - STL decomposition
#    - Lag scatter plots
#
# ### Key Findings:
# - ✅ **Forecastable: YES** - Significant predictable structure detected
# - **Non-stationary** - Requires first-order differencing (d=1)
# - **Strong seasonality** - 12-month period with 0.95 strength
# - **Strong trend** - Increasing trend with 0.98 strength
# - **No transformation needed** - Box-Cox λ ≈ 1.03
#
# ### Word Document Report:
# The comprehensive report includes:
# - Executive summary with key findings table
# - Detailed data overview and statistics
# - Statistical analysis with embedded visualizations
# - Seasonality analysis with decomposition plots
# - Autocorrelation analysis (ACF/PACF)
# - Forecastability assessment
# - Modeling recommendations (SARIMA, Holt-Winters, Prophet, ML approaches)
# - Professional formatting with color-coded tables and visual hierarchy
#
# The report has been exported as **retail_sales_analysis_report.docx** (680KB) and is ready for download!

# %% [markdown]
# ### Download the File

# %%
# Extract file ID from response
file_id = None
for block in response.content:
    if (block.type == 'bash_code_execution_tool_result'):
        if hasattr(block, 'content') and hasattr(block.content, 'content'):
            for result_block in block.content.content:
                if hasattr(result_block, 'file_id'):
                    file_id = result_block.file_id
                    break

# %%
if file_id:
    # Download the file
    file_content = client.beta.files.download(
        file_id=file_id,
        betas=["files-api-2025-04-14"]
    )

    # Save to disk
    with open("report.docx", "wb") as f:
        file_content.write_to_file(f.name)

# %% [markdown]
# ### Delete the Skill - Optional

# %%
# Step 1: Delete all versions
versions = client.beta.skills.versions.list(
    skill_id=skill.id,
    betas=["skills-2025-10-02"]
)

for version in versions.data:
    client.beta.skills.versions.delete(
        skill_id=skill.id,
        version=version.version,
        betas=["skills-2025-10-02"]
    )

# %%
# Step 2: Delete the Skill
client.beta.skills.delete(
    skill_id=skill.id,
    betas=["skills-2025-10-02"]
)
# Out:
# SkillDeleteResponse(id='skill_01WmT3LwX2Vpc2CYZpahhkoL', type='skill_deleted')
